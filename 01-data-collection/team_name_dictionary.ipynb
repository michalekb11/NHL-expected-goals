# %% [markdown]
# ## Create function that maps every possible team name to a 3 letter code

# %%
import json

# %%
# Define the mapping dictionary
team_name_map = {
    'anaheim ducks':'ANA',
    'ana ducks':'ANA',
    'ana':'ANA',
    'arizona coyotes':'ARI',
    'ari coyotes': 'ARI',
    'arz':'ARI',
    'ari':'ARI',
    'boston bruins':'BOS',
    'bos bruins':'BOS',
    'bos':'BOS',
    'buffalo sabres':'BUF',
    'buf sabres':'BUF',
    'buf':'BUF',
    'carolina hurricanes':'CAR',
    'car hurricanes':'CAR',
    'car':'CAR',
    'columbus blue jackets':'CBJ',
    'cbj blue jackets':'CBJ',
    'cbj':'CBJ',
    'calgary flames':'CGY',
    'cgy flames':'CGY',
    'cgy':'CGY',
    'chicago blackhawks':'CHI',
    'chicago black hawks':'CHI',
    'chi blackhawks':'CHI',
    'chi black hawks':'CHI',
    'chi':'CHI',
    'colorado avalanche':'COL',
    'col avalanche':'COL',
    'col':'COL',
    'dallas stars':'DAL',
    'dal stars':'DAL',
    'dal':'DAL',
    'detroit red wings':'DET',
    'det red wings':'DET',
    'det':'DET',
    'edmonton oilers':'EDM',
    'edm oilers':'EDM',
    'edm':'EDM',
    'florida panthers':'FLA',
    'fla panthers':'FLA',
    'fla':'FLA',
    'los angeles kings':'LAK',
    'la kings':'LAK',
    'lak':'LAK',
    'minnesota wild':'MIN',
    'min wild':'MIN',
    'min':'MIN',
    'montreal canadiens':'MTL',
    'mtl canadiens':'MTL',
    'mtl':'MTL',
    'new jersey devils':'NJD',
    'nj devils':'NJD',
    'njd':'NJD',
    'nashville predators':'NSH',
    'nsh predators':'NSH',
    'nsh':'NSH',
    'new york islanders':'NYI',
    'nyi islanders':'NYI',
    'ny islanders':'NYI',
    'nyi':'NYI',
    'new york rangers':'NYR',
    'nyr rangers':'NYR',
    'ny rangers':'NYR',
    'nyr':'NYR',
    'ottawa senators':'OTT',
    'ott senators':'OTT',
    'ott':'OTT',
    'philadelphia flyers':'PHI',
    'phi flyers':'PHI',
    'phi':'PHI',
    'pittsburgh penguins':'PIT',
    'pit penguins':'PIT',
    'pit':'PIT',
    'seattle kraken':'SEA',
    'sea kraken':'SEA',
    'sea':'SEA',
    'san jose sharks':'SJS',
    'sjs sharks':'SJS',
    'sj sharks':'SJS',
    'sjs':'SJS',
    'st. louis blues':'STL',
    'st louis blues':'STL',
    'stl blues':'STL',
    'stl':'STL',
    'tampa bay lightning':'TBL',
    'tbl lightning':'TBL',
    'tb lightning':'TBL',
    'tbl':'TBL',
    'toronto maple leafs':'TOR',
    'tor maple leafs':'TOR',
    'tor':'TOR',
    'vancouver canucks':'VAN',
    'van canucks':'VAN',
    'van':'VAN',
    'vegas golden knights':'VGK',
    'vgk golden knights':'VGK',
    'veg':'VGK',
    'vgk':'VGK',
    'winnipeg jets':'WPG',
    'wpg jets':'WPG',
    'win jets':'WPG',
    'win':'WIN',
    'wpg':'WPG',
    'washington capitals':'WSH',
    'wsh capitals':'WSH',
    'was capitals':'WSH',
    'was':'WSH',
    'wsh':'WSH'
}

# %%
# Write to text file using json
with open('../data/team_name_dictionary.txt', 'w') as fp:
    json.dump(team_name_map, fp)  # encode dict into JSON
