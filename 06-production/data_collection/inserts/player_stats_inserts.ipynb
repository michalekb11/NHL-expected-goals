# %% [markdown]
# ### Insert player and goalie statistics into MySQL tables

# %%
# Packages
import pandas as pd
import sqlalchemy
from mysql_class import MySQL

# %%
# User input
skater_path = '/Volumes/LUNANI/sports_betting_csv_backup/game_stats/skater_games.csv'
goalies_path = '/Volumes/LUNANI/sports_betting_csv_backup/game_stats/goalie_games.csv'

# %%
# Create the engine to connect to the MySQL database
mysql = MySQL()
mysql.connect()

# %% [markdown]
# ### Skaters

# %%
# Read in CSV files
skater = pd.read_csv(skater_path)
display(skater.head())
# Out:
# /var/folders/yk/qhxv13m50bl7fyrpnntydjgh0000gn/T/ipykernel_41910/746772625.py:2: DtypeWarning: Columns (26,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   skater = pd.read_csv(skater_path)
#    player_id team  game_num        date opponent  G  A  P  rating  PIM  ...  \
# 0  abramvi01  OTT         1  2021-05-05      MTL  0  0  0       0    0  ...
# 1  abramvi01  OTT         2  2021-05-08      WPG  0  0  0       0    0  ...
# 2  acciano01  FLA         1  2021-01-17      CHI  0  0  0       0    0  ...
# 3  acciano01  FLA         2  2021-01-19      CHI  0  0  0       0    0  ...
# 4  acciano01  FLA         3  2021-01-26      CBJ  0  0  0       2    0  ...
#
#     FOW   FOL  FOW_pct  player_name  age  season  home_away_status  result  \
# 0   0.0   0.0      NaN          NaN  NaN     NaN               NaN     NaN
# 1   0.0   0.0      NaN          NaN  NaN     NaN               NaN     NaN
# 2   5.0  10.0     33.3          NaN  NaN     NaN               NaN     NaN
# 3   5.0  10.0     33.3          NaN  NaN     NaN               NaN     NaN
# 4  12.0   7.0     63.2          NaN  NaN     NaN               NaN     NaN
#
#    S_perc  FOW_perc
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN
# 3     NaN       NaN
# 4     NaN       NaN
#
# [5 rows x 33 columns]

# %%
# Select the correct columns, rename, and order them
skater = skater[['player_id', 'team', 'game_num', 'date', 'opponent', 'G', 'A', 'P', 'rating', 'PIM', 'EVG', 'PPG', 'SHG', 'GWG', 'EVA', 'PPA', 'SHA', 'S', 'S_perc', 'shifts', 'TOI', 'HIT', 'BLK', 'FOW', 'FOL', 'FOW_perc']].rename(columns={'S_perc':'S_pct', 'FOW_perc':'FOW_pct'})

# %%
# Insert into skater statistics table
skater.to_sql(name = 'skater_game', con=mysql.engine, schema='nhl', if_exists='append', index=False)
# Out:
# -1

# %%
# Empty the df
#skater = skater.iloc[0:0]
#skater.to_csv(skater_path, header=True, index=False)

# %% [markdown]
# ### Goalies

# %%
# Read in CSV files
goalie = pd.read_csv(goalies_path)
display(goalie.head())
# Out:
#    player_id player_name  age  season  game_num        date team opponent  \
# 0  allenja01  jake allen   30    2021         1  2021-01-18  MTL      EDM
# 1  allenja01  jake allen   30    2021         2  2021-01-21  MTL      VAN
# 2  allenja01  jake allen   30    2021         3  2021-01-30  MTL      CGY
# 3  allenja01  jake allen   30    2021         4  2021-02-02  MTL      VAN
# 4  allenja01  jake allen   30    2021         5  2021-02-06  MTL      OTT
#
#    home_away_status result decision  GA  SA  SV  SV_perc  shutout  PIM  \
# 0                 0      W        W   1  26  25    0.962        0    0
# 1                 0      W        W   3  17  14    0.824        0    0
# 2                 1      L        L   1  32  31    0.969        0    0
# 3                 1      W        W   3  39  36    0.923        0    0
# 4                 0      W        W   1  35  34    0.971        0    0
#
#          TOI
# 0  59.650000
# 1  59.766667
# 2  58.850000
# 3  59.666667
# 4  60.000000

# %%
# Select the correct columns, rename, and order them
goalie = goalie[['player_id', 'team', 'game_num', 'date', 'opponent', 'decision', 'GA', 'SA', 'SV', 'SV_perc', 'shutout', 'PIM', 'TOI']].rename(columns={'SV_perc':'SV_pct'})

# %%
# Insert into goalie statistics table
goalie.to_sql(name = 'goalie_game', con=mysql.engine, schema='nhl', if_exists='append', index=False)
# Out:
# -1

# %%
# Empty the df
#goalie = goalie.iloc[0:0]
#goalie.to_csv(goalie_path, header=True, index=False)
