# %% [markdown]
# ### Insert player and goalie statistics into MySQL tables

# %%
# Packages
import pandas as pd
from MySQLClass import MySQL

# %%
# User input
# skater_path = '/Volumes/LUNANI/sports_betting_csv_backup/game_stats/skater_games.csv'
# goalies_path = '/Volumes/LUNANI/sports_betting_csv_backup/game_stats/goalie_games.csv'

skater_path = '/Users/bryanmichalek/Documents/GitHub_Personal/sports_betting_data/data/historic_batch/stats/skater_2.csv'
goalies_path = '/Users/bryanmichalek/Documents/GitHub_Personal/sports_betting_data/data/historic_batch/stats/goalie_2.csv'

# %%
# Create the engine to connect to the MySQL database
mysql = MySQL()
mysql.connect()

# %% [markdown]
# ### Skaters

# %%
# Read in CSV files
skater = pd.read_csv(skater_path)
display(skater.head())
# Out:
#    player_id        player_name  age  season  game_num        date team  \
# 0  abbotsp01     spencer abbott   28    2017         1  2017-01-05  CHI
# 1  abdelju01  justin abdelkader   29    2017         1  2016-10-13  DET
# 2  abdelju01  justin abdelkader   29    2017         2  2016-10-15  DET
# 3  abdelju01  justin abdelkader   29    2017         3  2016-10-17  DET
# 4  abdelju01  justin abdelkader   29    2017         4  2016-10-19  DET
#
#   opponent  home_away_status result  ...  SHA  S  S_perc  shifts        TOI  \
# 0      BUF               1.0      W  ...    0  1     0.0      12   8.566667
# 1      TBL               0.0      L  ...    0  2     0.0      21  15.283333
# 2      FLA               0.0      L  ...    0  1     0.0      21  14.533333
# 3      OTT               1.0      W  ...    0  0     NaN      17  13.450000
# 4      NYR               0.0      W  ...    0  0     NaN      19  16.116667
#
#    HIT  BLK  FOW  FOL  FOW_perc
# 0    0  0.0  0.0  0.0       NaN
# 1    6  0.0  0.0  0.0       NaN
# 2    1  0.0  0.0  0.0       NaN
# 3    2  1.0  0.0  0.0       NaN
# 4    4  2.0  0.0  0.0       NaN
#
# [5 rows x 31 columns]

# %%
# Select the correct columns, rename, and order them
skater = skater[['player_id', 'team', 'game_num', 'date', 'opponent', 'G', 'A', 'P', 'rating', 'PIM', 'EVG', 'PPG', 'SHG', 'GWG', 'EVA', 'PPA', 'SHA', 'S', 'S_perc', 'shifts', 'TOI', 'HIT', 'BLK', 'FOW', 'FOL', 'FOW_perc']].rename(columns={'S_perc':'S_pct', 'FOW_perc':'FOW_pct'})

# %%
# Insert into skater statistics table
skater.to_sql(name = 'skater_game', con=mysql.engine, schema='nhl', if_exists='append', index=False)
# Out:
# -1

# %%
# Empty the df
#skater = skater.iloc[0:0]
#skater.to_csv(skater_path, header=True, index=False)

# %% [markdown]
# ### Goalies

# %%
# Read in CSV files
goalie = pd.read_csv(goalies_path)
display(goalie.head())
# Out:
#    player_id player_name  age  season  game_num        date team opponent  \
# 0  allenja01  jake allen   26    2017         1  2016-10-12  STL      CHI
# 1  allenja01  jake allen   26    2017         2  2016-10-13  STL      MIN
# 2  allenja01  jake allen   26    2017         3  2016-10-18  STL      VAN
# 3  allenja01  jake allen   26    2017         4  2016-10-20  STL      EDM
# 4  allenja01  jake allen   26    2017         5  2016-10-22  STL      CGY
#
#    home_away_status result decision  GA  SA  SV  SV_perc  shutout  PIM  \
# 0                 0      W        W   2  19  17    0.895        0    0
# 1                 1      W        W   2  21  19    0.905        0    0
# 2                 0   L-OT        O   2  26  24    0.923        0    0
# 3                 0      L        L   2  22  20    0.909        0    0
# 4                 0      W        W   4  27  23    0.852        0    0
#
#          TOI
# 0  60.000000
# 1  60.000000
# 2  61.666667
# 3  59.300000
# 4  60.000000

# %%
# Select the correct columns, rename, and order them
goalie = goalie[['player_id', 'team', 'game_num', 'date', 'opponent', 'decision', 'GA', 'SA', 'SV', 'SV_perc', 'shutout', 'PIM', 'TOI']].rename(columns={'SV_perc':'SV_pct'})

# %%
# Insert into goalie statistics table
goalie.to_sql(name = 'goalie_game', con=mysql.engine, schema='nhl', if_exists='append', index=False)
# Out:
# -1

# %%
# Empty the df
#goalie = goalie.iloc[0:0]
#goalie.to_csv(goalie_path, header=True, index=False)
