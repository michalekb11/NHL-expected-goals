# %%
player_names = ['Nicholas Abruzzese', 'Noel Acciari', 'Calen Addison',
'Egor Afanasyev', 'Andrew Agozzino', 'Sebastian Aho',
'Nikita Alexandrov', 'Alexander Alexeyev', 'Frédéric Allard',
'Wade Allison', 'Michael Amadio', 'Nils Åman',
'Jaret Anderson-Dolan', 'Josh Anderson', 'Joey Anderson',
'Lias Andersson', 'Michael Anderson', 'Rasmus Andersson',
'Andy Andreoff', 'Tyler Angle', 'Mason Appleton', 'Josh Archibald',
'Joel Armia', 'Viktor Arvidsson', 'Rasmus Asplund',
'Zach Aston-Reese', 'Andreas Athanasiou', 'Ronald Attard',
'Nicolas Aube-Kubel', 'Jonathan Marchessault', 'Mikael Backlund',
'Nicklas Bäckström', 'Kevin Bahl', 'Josh Bailey',
'Rudolfs Balcers', 'Alexander Barabanov', 'Ivan Barbashev',
'Cole Bardreau', 'Aleksander Barkov', 'Alex Barre-Boulet',
'Tyson Barrie', 'Justin Barron', 'Morgan Barron', 'Mathew Barzal',
'Nathan Bastian', 'Drake Batherson', 'Gavin Bayreuther',
'Jake Bean', 'Ethan Bear', 'Nathan Beaulieu',
'Anthony Beauvillier', 'Adam Beckman', 'Owen Beck',
'Pierre-Édouard Bellemare', 'Kieffer Bellows', 'Alex Belzile',
'Emil Bemström', 'Matthew Beniers', 'Sam Bennett', 'Matt Benning',
'Jamie Benn', 'Jordie Benn', 'Simon Benoit', 'Tyler Benson',
'Patrice Bergeron', 'Jonatan Berggren', 'Jacob Bernard-Docker',
'Tim Berni', 'Tyler Bertuzzi', 'William Bitten', 'Anders Bjork',
'Marcus Björk', 'Oliver Bjorkstrand', 'Tobias Björnfot',
'Nick Bjugstad', 'Colin Blackwell', 'Sammy Blais',
'Nick Blankenburg', 'Anton Blidh', 'Teddy Blueger', 'Matej Blumel',
'Brock Boeser', 'Zach Bogosian', 'Samuel Bolduc', 'Matt Boldy',
'Nick Bonino', 'Adam Boqvist', 'Jesper Boqvist',
'Thomas Bordeleau', 'William Borgen', 'Henrik Borgström',
'Mark Borowiecki', 'Robert Bortuzzo', 'Evan Bouchard',
'Shane Bowers', 'Travis Boyd', 'Erik Brännström',
'Derick Brassard', 'Jesper Bratt', 'Justin Braun',
'Guillaume Brisebois', 'Philip Broberg', 'Jonas Brodin',
'T.J. Brodie', 'Jonny Brodzinski', 'Connor Brown', 'Josh Brown',
'Logan Brown', 'Patrick Brown', 'Jacob Bryson', 'Pavel Buchnevich',
'Michael Bunting', 'André Burakovsky', 'Callahan Burke',
'Brent Burns', 'Kyle Burroughs', 'Quinton Byfield', 'Bowen Byram',
'Drake Caggiula', 'Kyle Capobianco', 'Michael Carcone',
'Brandon Carlo', 'Gabriel Carlsson', 'John Carlson',
'Lucas Carlsson', 'Ryan Carpenter', 'Alexandre Carrier',
'Connor Carrick', 'Sam Carrick', 'William Carrier', 'Jeff Carter',
'Jackson Cates', 'Noah Cates', 'Cole Caufield', 'Cody Ceci',
'Erik Černák', 'Thomas Chabot', 'Rourke Chartier',
'Jalen Chatfield', 'Ben Chiarot', 'Alex Chiasson',
'Yegor Chinakhov', 'Dennis Cholowski', 'Jake Christiansen',
'Jakob Chychrun', 'Filip Chytil', 'Nick Cicek', 'Anthony Cirelli',
'Casey Cizikas', 'Kale Clague', 'Brandt Clarke', 'Kyle Clifford',
'Connor Clifton', 'Cal Clutterbuck', 'Dylan Coghlan',
'Andrew Cogliano', 'Ian Cole', 'Blake Coleman', 'Ross Colton',
'J.T. Compher', 'Max Comtois', 'Lucas Condotta', 'Kyle Connor',
'Andrew Copp', 'Paul Cotter', 'Nick Cousins', 'Logan Couture',
'Charlie Coyle', 'Dylan Cozens', 'Joseph Cramarossa',
'Kyle Criscuolo', 'Sidney Crosby', 'Lawson Crouse',
'William Cuylle', 'Austin Czarnik', 'Kirby Dach',
'Evgenii Dadonov', 'Rasmus Dahlin', 'Zac Dalpe', 'Phillip Danault',
'Justin Danforth', 'Laurent Dauphin', 'Jeremy Davies',
'Jean-Sebastien Dea', 'Anthony DeAngelo', 'Alex DeBrincat',
'Jake DeBrusk', 'Calvin de Haan', 'Ty Dellandrea', 'Dylan DeMelo',
'Jason Demers', 'Grigori Denisenko', 'Semyon Der-Arguchintsev',
'Travis Dermott', 'Vincent Desharnais', 'Nick DeSimone',
'Nicolas Deslauriers', 'Elliot Desnoyers', 'Connor Dewar',
'Jason Dickinson', 'Phillip Di Giuseppe', 'Brenden Dillon',
'Noah Dobson', 'Max Domi', 'Ryan Donato', 'Pavel Dorofeyev',
'Drew Doughty', 'Nic Dowd', 'Leon Draisaitl', 'Sheldon Dries',
'Jonathan Drouin', 'Jack Drury', 'Jamie Drysdale', 'Dillon Dubé',
'Pierre-Luc Dubois', 'Matt Duchene', 'Anthony Duclair',
'Walker Duehr', 'William Dufour', 'Brandon Duhaime',
'Mathew Dumba', 'Brian Dumoulin', 'Joshua Dunne', 'Vince Dunn',
'Arnaud Durandeau', 'Sean Durzi', 'Christian Dvorak',
'Jordan Eberle', 'Alexander Edler', 'Joel Edmundson',
'Simon Edvinsson', 'Nikolaj Ehlers', 'Jack Eichel', 'Aaron Ekblad',
'Mattias Ekholm', 'William Eklund', 'Oliver Ekman-Larsson',
'Lars Eller', 'Andreas Englund', 'Pierre Engvall',
'Mackenzie Entwistle', 'Joel Eriksson Ek', 'Adam Erne',
'Luke Evangelista', 'Jake Evans', 'Michael Eyssimont',
'Dante Fabbro', 'Robby Fabbri', 'Brock Faber', 'Samuel Fagemo',
'Radek Faksa', 'Joel Farabee', 'Sean Farrell', 'Hudson Fasching',
'Jesper Fast', 'Justin Faulk', 'Taylor Fedun', 'Martin Fehérváry',
'Mario Ferraro', 'Kevin Fiala', 'Christian Fischer',
'Casey Fitzgerald', 'Trey Fix-Wolansky', 'Cale Fleury',
'Haydn Fleury', 'Warren Foegele', 'Tyson Foerster',
'Steven Fogarty', 'Marcus Foligno', 'Nick Foligno', 'Callan Foote',
'Nolan Foote', 'Derek Forbort', 'Filip Forsberg',
'Gustav Forsling', 'Gabriel Fortier', 'Jean-Luc Foudy',
'Liam Foudy', 'Cam Fowler', 'Adam Fox', 'C.J. Suess',
'Trent Frederic', 'Mark Friedman', 'Jesper Frödén', 'Byron Froese',
'Morgan Frost', 'Jonah Gadjovich', 'Sam Gagner', 'Alex Galchenyuk',
'Brendan Gallagher', 'Dylan Gambrell', 'Conor Garland',
'Frédérick Gaudreau', 'Johnny Gaudreau', 'Brendan Gaunce',
'Julien Gauthier', 'Vladislav Gavrikov', 'Glenn Gawdin',
'Morgan Geekie', 'Dennis Gilbert', 'Adam Ginning', 'Mark Giordano',
'Samuel Girard', 'Zemgus Girgensons', 'Claude Giroux',
'Damien Giroux', 'Cody Glass', 'Luke Glendening', 'Alex Goligoski',
'Barclay Goodrow', 'Shayne Gostisbehere', 'Yanni Gourde',
'Mikael Granlund', 'Derek Grant', 'Kevin Gravel', 'Ryan Graves',
'Jordan Greenway', 'A.J. Greer', 'Noah Gregor', 'Ridly Greig',
'Jordan Gross', 'Benoit-Olivier Groulx', 'Jonathan Gruden',
'Carl Grundström', 'Matt Grzelcyk', 'Radko Gudas',
'Erik Gudbranson', 'Max Guenette', 'Dylan Guenther',
'Jake Guentzel', 'Kaiden Guhle', 'Denis Gurianov',
'Daniil Gushchin', 'David Gustafsson', 'Erik Gustafsson',
'Dave Gust', 'Cole Guttman', 'Brandon Hagel', 'Robert Hägg',
'Nicolas Hague', 'Libor Hájek', 'Jani Hakanpää', 'Filip Hallander',
'Taylor Hall', 'James Hamblin', 'Dougie Hamilton',
'Travis Hamonic', 'Noah Hanifin', 'Joel Hanley', 'Mike Hardman',
'Jansen Harkins', 'Thomas Harley', 'Ben Harpur', 'Jordan Harris',
'Scott Harrington', 'Ryan Hartman', 'Rafaël Harvey-Pinard',
'Garnet Hathaway', 'Erik Haula', 'John Hayden', 'Kevin Hayes',
'Barrett Hayton', 'Dillon Heatherington', 'Victor Hedman',
'Danton Heinen', 'Ville Heinola', 'Miro Heiskanen',
'Drew Helleson', 'Darren Helm', 'Adam Henrique',
'Aleksi Heponiemi', 'Tomáš Hertl', 'Matthew Highmore',
'Vinnie Hinostroza', 'Roope Hintz', 'Akito Hirose', 'Taro Hirose',
'Nico Hischier', 'Hayden Hodgson', 'Mike Hoffman',
'Nils Hoglander', 'Nick Holden', 'Justin Holl', 'Dylan Holloway',
'Mac Hollowell', 'Pontus Holmberg', 'Simon Holmström',
'Alexander Holtz', 'Patric Hörnqvist', 'Bo Horvat', 'Brett Howden',
'Filip Hronek', 'Jonathan Huberdeau', 'Charles Hudon',
'Jack Hughes', 'Luke Hughes', 'Quinn Hughes', 'Brad Hunt',
'Dryden Hunt', 'Ben Hutton', 'Zach Hyman', 'Alex Iafallo',
'Bokondji Imama', 'Vincent Iorio', 'Matt Irwin', 'Mark Jankowski',
'Mattias Janmark', 'Calle Järnkrok', 'Seth Jarvis',
'Tanner Jeannot', 'Jan Jeník', 'Boone Jenner', 'Nick Jensen',
'David Jiříček', 'Lucas Johansen', 'Marcus Johansson',
'Ryan Johansen', 'Andreas Johnsson', 'Erik Johnson',
'Jack Johnson', 'Kent Johnson', 'Reese Johnson', 'Ross Johnston',
'Tyler Johnson', 'Wyatt Johnston', 'Henri Jokiharju',
'Caleb Jones', 'Max Jones', 'Seth Jones', 'Zachary Jones',
'Axel Jonsson Fjällby', 'Mathieu Joseph', 'Pierre-Olivier Joseph',
'Dakota Joshua', 'Roman Josi', 'Tyson Jost', 'Noah Juulsen',
'Nazem Kadri', 'Wyatt Kaiser', 'Kaapo Kakko', 'Arthur Kaliyev',
'David Kämpf', 'Evander Kane', 'Patrick Kane', 'Kasperi Kapanen',
'Kirill Kaprizov', 'Erik Karlsson', 'Fredrik Karlström',
'William Karlsson', 'Ondřej Kaše', 'Marco Kasper', 'Zack Kassian',
'Mark Kastelic', 'Boris Katchouk', 'Martin Kaut', 'Milos Kelemen',
'Clayton Keller', 'Parker Kelly', 'Adrian Kempe',
'Alexander Kerfoot', 'Matthew Kessel', 'Michael Kesselring',
'Phil Kessel', 'Jujhar Khaira', 'Matt Kiersted', 'Alex Killorn',
'Justin Kirkland', 'Joel Kiviranta', 'Tyler Kleven',
'John Klingberg', 'Samuel Knazko', 'Matthew Knies',
'Nikolai Knyzhov', 'Cole Koepke', 'Otto Koivula', 'Keegan Kolesar',
'Vladislav Kolyachonok', 'Travis Konecny', 'Anže Kopitar',
'Joona Koppanen', 'Kaedan Korczak', 'Klim Kostin',
'Jesperi Kotkaniemi', 'Johnathan Kovacevic', 'Filip Kral',
'Vitali Kravtsov', 'Peyton Krebs', 'Chris Kreider', 'David Krejčí',
'Torey Krug', 'Dominik Kubalík', 'Nikita Kucherov',
'Karson Kuhlman', 'Brett Kulak', 'Dmitry Kulikov', 'Luke Kunin',
'Rasmus Kupari', 'Sean Kuraly', 'Philipp Kurashev',
'Andrei Kuzmenko', 'Evgeny Kuznetsov', 'Jordan Kyrou',
'Kevin Labanc', 'Jackson LaCombe', 'Tanner Laczynski',
'Sam Lafferty', 'Alexis Lafrenière', 'Patrik Laine',
'Maxime Lajoie', 'Dylan Larkin', 'Adam Larsson', 'Jacob Larsson',
'Scott Laughton', 'Jakub Lauko', 'Jeremy Lauzon', 'Curtis Lazar',
'Brett Leason', 'Nick Leddy', 'Anders Lee', 'Artturi Lehkonen',
'Josh Leivo', 'Brendan Lemieux', 'John Leonard', 'Jake Leschyshyn',
'Kris Letang', 'Vinni Lettieri', 'Anton Levtchi', 'Trevor Lewis',
'Timothy Liljegren', 'Oskar Lindblom', 'Esa Lindell',
'Ryan Lindgren', 'Elias Lindholm', 'Hampus Lindholm',
'Gustav Lindström', 'Jake Livingstone', 'Blake Lizotte',
'William Lockwood', 'Ryan Lomberg', 'Steven Lorentz', 'Adam Lowry',
'Jake Lucchini', 'Milan Lucic', 'Matt Luff', 'Anton Lundell',
'Isac Lundeström', 'Nils Lundkvist', 'Eetu Luostarinen',
'Joona Luoto', 'Olle Lycksell', 'Ilya Lyubushkin', 'Olli Määttä',
'Matias Maccelli', 'Kurtis MacDermid', 'Jacob MacDonald',
'Zack MacEwen', 'Connor Mackey', 'Nathan MacKinnon',
'Saku Mäenalanen', 'Josh Mahura', 'Cale Makar', 'Beck Malenstyn',
'Denis Malgin', 'Evgeni Malkin', 'Brad Malone', 'Mikhail Maltsev',
'Andrew Mangiapane', 'Josh Manson', 'Anthony Mantha',
'Brad Marchand', 'Kirill Marchenko', 'Mason Marchment',
'John Marino', 'Mitch Marner', 'Pat Maroon', 'Alec Martinez',
'Jordan Martinook', 'Matt Martin', 'Mike Matheson',
'Auston Matthews', 'Scott Mayfield', 'Dysin Mayo',
'Charlie McAvoy', 'Jack McBain', 'Jake McCabe', 'Jared McCann',
'Michael McCarron', 'Connor McDavid', 'Aidan McDonough',
'Ryan McDonagh', 'Brock McGinn', 'Hugh McGing', 'Dylan McIlrath',
'Roland McKeown', 'Hunter McKown', 'Marc McLaughlin',
'Michael McLeod', 'Ryan McLeod', 'Bobby McMann',
'Connor McMichael', 'Brayden McNabb', 'Mason Mctavish',
'Cole McWard', 'Jayson Megna', 'Jaycob Megna', 'Timo Meier',
'Dawson Mercer', 'Dakota Mermis', 'Jonathon Merrill',
'Victor Mete', 'Ben Meyers', 'Carson Meyer', 'Jacob Middleton',
'Ilya Mikheyev', 'Niko Mikkola', 'Sonny Milano', 'Colin Miller',
'J.T. Miller', "K'Andre Miller", 'Daniil Miromanov',
'Ian Mitchell', 'Casey Mittelstadt', 'Sean Monahan',
'Brandon Montour', 'Trevor Moore', 'Josh Morrissey', 'J.J. Moser',
'Tyler Motte', 'Jacob Moverare', 'Connor Murphy', 'Ryan Murray',
'Jake Muzzin', 'Philippe Myers', 'Tyler Myers',
'Vladislav Namestnikov', 'Martin Nečas', 'Jake Neighbours',
'Brock Nelson', 'Patrik Nemeth', 'Nikita Nesterenko',
'Alex Newhook', 'Valeri Nichushkin', 'Nino Niederreiter',
'Markus Niemeläinen', 'Matthew Nieto', 'Stefan Noesen',
'Joshua Norris', 'Tomáš Nosek', 'Thomas Novak',
'Ryan Nugent-Hopkins', 'Darnell Nurse', 'Alexander Nylander',
'William Nylander', 'Gustav Nyquist', "Liam O'Brien",
"Drew O'Connor", "Logan O'Connor", 'Jordan Oesterle',
'Nikita Okhotyuk', 'Kyle Okposo', 'Oskar Olausson',
'Jamie Oleksiak', 'Mathieu Olivier', 'Frederik Olofsson',
'Gustav Olofsson', 'Victor Olofsson', "Ryan O'Reilly",
'Dmitry Orlov', 'T.J. Oshie', 'Alex Ovechkin', 'Brayden Pachal',
'Max Pacioretty', 'Jean-Gabriel Pageau', 'Ondřej Palát',
'Kyle Palmieri', 'Artemi Panarin', 'Colton Parayko', 'Zach Parise',
'Juuso Parssinen', 'David Pastrňák', 'Nick Paul', 'Joe Pavelski',
'Tanner Pearson', 'Lane Pederson', 'Andrew Peeke', 'Adam Pelech',
'Jakob Pelletier', 'Nicklaus Perbix', 'Cole Perfetti',
'David Perron', 'Corey Perry', 'Brett Pesce', 'Nic Petan',
'Jacob Peterson', 'John-Jason Peterka', 'Jeff Petry',
'Elias Pettersson', 'Marcus Pettersson', 'Michael Pezzetta',
'Isaak Phillips', 'Matthew Phillips', 'Luke Philp',
'Alex Pietrangelo', 'Lawrence Pilut', 'Shane Pinto', 'Neal Pionk',
'Rem Pitlick', 'Tyler Pitlick', 'Vasily Podkolzin',
'Ryan Poehling', 'Brayden Point', 'Tucker Poolman',
'Derrick Pouliot', 'Samuel Poulin', 'Owen Power',
'Aliaksei Protas', 'Ivan Provorov', 'Jesse Puljujärvi',
'Ryan Pulock', 'Mikael Pyyhtia', 'Jack Quinn', 'Darren Raddysh',
'Taylor Raddysh', 'Rickard Rakell', 'Mikko Rantanen',
'Sampo Ranta', 'Adam Raska', 'Michael Rasmussen', 'Jack Rathbone',
'Aatu Raty', 'Lucas Raymond', 'Ryan Reaves', 'Pavol Regenda',
'Alec Regula', 'Kristian Reichel', 'Lukas Reichel', 'Mike Reilly',
'Sam Reinhart', 'Sheldon Rempal', 'Dan Renouf', 'Anthony Richard',
'Justin Richards', 'Morgan Rielly', 'Rasmus Ristolainen',
'Brett Ritchie', 'Nick Ritchie', 'Jason Robertson',
'Nicholas Robertson', 'Buddy Robinson', 'Eric Robinson',
'Tristen Robins', 'Evan Rodrigues', 'Alexander Romanov',
'Jonas Røndbjerg', 'Kevin Rooney', 'Filip Roos', 'Calle Rosén',
'Jack Roslovic', 'Marco Rossi', 'Lukáš Rousek', 'Matt Roy',
'Nicolas Roy', 'Chad Ruhwedel', 'Bryan Rust', 'Jan Rutta',
'Adam Ružička', 'Derek Ryan', 'Brandon Saad', 'Robin Salo',
'Dylan Samberg', 'Dmitri Samorukov', 'Mattias Samuelsson',
'Jake Sanderson', 'Rasmus Sandin', 'Zach Sanford',
'Travis Sanheim', 'Steven Santini', 'David Savard',
'Marco Scandella', 'Mark Scheifele', 'Brayden Schenn',
'Luke Schenn', 'Nick Schmaltz', 'Nate Schmidt', 'Braden Schneider',
'Corey Schueneman', 'Justin Schultz', 'Jaden Schwartz',
'Lukáš Sedlák', 'Nick Seeler', 'Tyler Seguin', 'Moritz Seider',
'Brett Seney', 'Mikhail Sergachev', 'Damon Severson',
'Yegor Sharangovich', 'Kevin Shattenkirk', 'Mason Shaw',
'Riley Sheahan', 'Conor Sheary', 'Kiefer Sherwood', 'Devin Shore',
'Jonas Siegenthaler', 'Jakob Silfverberg', 'Cole Sillinger',
'Radim Šimek', 'Wayne Simmonds', 'Colton Sissons', 'Jeff Skinner',
'Brady Skjei', 'Juraj Slafkovsky', 'Jaccob Slavin',
'Brendan Smith', 'Cole Smith', 'Craig Smith', 'Givani Smith',
'Nathan Smith', 'Reilly Smith', 'Ty Smith', 'Joe Snively',
'Elmer Soderblom', 'Victor Söderström', 'Egor Sokolov',
'Nikita Soshnikov', 'Carson Soucy', 'Jordan Spence',
'Daniel Sprong', 'Jared Spurgeon', 'Eric Staal', 'Jordan Staal',
'Marc Staal', 'Steven Stamkos', 'Logan Stanley', 'Paul Stastny',
'Spencer Stastney', 'Troy Stecher', 'Sam Steel', 'Oskar Steen',
'Alex Steeves', 'Kevin Stenlund', 'Derek Stepan',
'Chandler Stephenson', 'Riley Stillman', 'Mark Stone',
'Michael Stone', 'Anton Strålman', 'Austin Strand', 'Dylan Strome',
'Ryan Strome', 'Marián Studenič', 'Jack Studnicka', 'Tim Stützle',
'Nico Sturm', 'Oskar Sundqvist', 'Pius Suter', 'Ryan Suter',
'Nick Suzuki', 'Andrei Svechnikov', 'Evgeny Svechnikov',
'Stanislav Svozil', 'Nick Swaney', 'Billy Sweezey',
'Brandon Tanev', 'Chris Tanev', 'Vladimir Tarasenko',
'Tomáš Tatar', 'John Tavares', 'Joel Teasdale', 'Teuvo Teräväinen',
'Troy Terry', 'Shea Theodore', 'Robert Thomas', 'Tage Thompson',
'Tyce Thompson', 'Lassi Thomson', 'Henry Thrun', 'Chris Tierney',
'Conor Timmins', 'Jarred Tinordi', 'Owen Tippett', 'Brady Tkachuk',
'Matthew Tkachuk', 'Devon Toews', 'Jonathan Toews',
'Tyler Toffoli', 'Eeli Tolvanen', 'Philip Tomasino',
'Dominic Toninato', 'Alexey Toropchenko', 'Yakov Trenin',
'Vincent Trocheck', 'Jacob Trouba', 'Alex Tuch', 'Tyler Tucker',
'Riley Tufte', 'Alex Turcotte', 'Urho Vaakanainen',
'Juuso Valimaki', 'James van Riemsdyk', 'Trevor van Riemsdyk',
'Frank Vatrano', 'Joe Veleno', 'Carter Verhaeghe', 'Jimmy Vesey',
'Jeffrey Viel', 'Gabriel Vilardi', 'Alex Vlasic',
'Marc-Édouard Vlasic', 'Jakub Voráček', 'Jakub Vrána',
'Austin Wagner', 'Chris Wagner', 'Oliver Wahlstrom',
'Nathan Walker', 'Samuel Walker', 'Sean Walker', 'Jake Walman',
'Austin Watson', 'MacKenzie Weegar', 'Alexander Wennberg',
'Zach Werenski', 'Blake Wheeler', 'Colin White', 'Colton White',
'Zach Whitecloud', 'Chris Wideman', 'Maxwell Willman',
'Tom Wilson', 'Christian Wolanin', 'Miles Wood',
'Parker Wotherspoon', 'Shane Wright', 'Arber Xhekaj',
'Kailer Yamamoto', 'Jesse Ylönen', 'Cameron York', 'Pavel Zacha',
'Filip Zadina', 'Nikita Zadorov', 'Nikita Zaitsev', 'Yegor Zamula',
'Jakub Zbořil', 'Trevor Zegras', 'Fabian Zetterlund',
'Mika Zibanejad', 'Radim Zohorna', 'Artem Zub', 'Mats Zuccarello',
'Jason Zucker']

# %%
def clean_name(name):
    # Set up replace dictionary
    replace_dict = {
        # Special characters
        #'Å':'A',
        'å':'a',
        'ä':'a',
        'á':'a',
        #'Č':'C',
        'č':'c',
        #'É':'E',
        'é':'e',
        'ë':'e',
        'è':'e',
        'í':'i',
        'ň':'n',
        'ö':'o',
        'ø':'o',
        'ř':'r',
        #'Š':'S',
        'š':'s',
        'ü':'u',
        'ž':'z',
        # Components of name

        # Other punctuation
        '.':'',
        '-':' ',
        "'":''
    }
    # Strip white space
    name = name.strip()
    # Lowercase
    name = name.lower()
    # Replace characters, punctuation, phrases
    for k, v in replace_dict.items():
        name = name.replace(k, v)

    # Return cleaned name
    return name

# %%
player_names_clean = [clean_name(name) for name in player_names]
